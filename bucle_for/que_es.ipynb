# %% [markdown]
# # 📚 Guía Completa: El Bucle For en Python
#
# ---
#
# ## 1. Definición Técnica y Conceptual
#
# ### ¿Qué es un bucle for?
# Un **bucle for** es una estructura de control que permite repetir un bloque de código un número determinado de veces. Es ideal cuando sabes cuántas iteraciones necesitas.
#
# ### Analogía de la vida real
# Imagina que necesitas leer 10 libros de una biblioteca. En lugar de escribir las instrucciones 10 veces, dices: *"Para cada libro en la pila, léelo"*. Así es como funciona un bucle for.
#
# ---
#
# ## 2. Anatomía del Bucle For
#
# ```python
# # Estructura básica del bucle for
# for variable in secuencia:
#     # Código a ejecutar en cada iteración
#     print(variable)
# ```
#
# **Componentes:**
# - **`for`**: Palabra clave que inicia el bucle
# - **`variable`**: Toma el valor de cada elemento en la secuencia
# - **`in`**: Palabra clave que indica "en"
# - **`secuencia`**: Lista, tupla, rango, string, etc.
# - **`:`**: Indica el inicio del bloque de código
# - **Indentación**: Define el cuerpo del bucle
#
# ---
#
# ## 3. Flujo de Ejecución Paso a Paso
#
# En cada iteración ocurren los siguientes pasos:
#
# 1. **Obtener elemento**: Se toma el primer elemento de la secuencia
# 2. **Asignar variable**: Se asigna a la variable de iteración
# 3. **Ejecutar código**: Se ejecuta el bloque indentado
# 4. **Siguiente elemento**: Vuelve al paso 1 con el siguiente elemento
# 5. **Fin**: Cuando no hay más elementos, termina el bucle

# %%
# Flujo de ejecución visual
numeros = [1, 2, 3]

for numero in numeros:
    print(f"Iteración con valor: {numero}")

print("\n--- EXPLICACIÓN DEL FLUJO ---")
print("1. Inicio: Python ve la lista [1, 2, 3]")
print("2. Iteración 1: numero = 1")
print("3. Iteración 2: numero = 2")
print("4. Iteración 3: numero = 3")
print("5. Fin: No hay más elementos, sale del bucle")

# %% [markdown]
# ---
#
# ## 4. Ejemplo Básico: Contador Simple
#
# Un contador es el uso más fundamental del bucle for. Usamos `range()` para generar números.

# %%
# Usar range() para crear un contador
print("=== CONTADOR SIMPLE ===")

for i in range(1, 6):  # range(inicio, fin) - fin no se incluye
    print(f"Contador: {i}")

print("\n✓ Explicación:")
print("  - range(1, 6) genera números del 1 al 5")
print("  - La variable 'i' toma cada valor automáticamente")
print("  - Se ejecuta 5 veces")

# %% [markdown]
# ---
#
# ## 5. Ejemplo Intermedio: Recorrer una Lista/Arreglo
#
# Aprendemos a iterar sobre colecciones de datos y acceder a índices.

# %%
# Recorrer una lista de frutas
print("\n=== LISTA DE FRUTAS ===")

frutas = ["manzana", "banana", "naranja", "uva"]

for fruta in frutas:
    print(f"Fruta: {fruta.capitalize()}")

# También puedes acceder al índice
print("\n=== CON ÍNDICE ===")

for indice, fruta in enumerate(frutas):
    print(f"Posición {indice}: {fruta}")

print("\n✓ Explicación:")
print("  - Itera sobre cada elemento de la lista")
print("  - enumerate() proporciona índice y valor simultáneamente")
print("  - Muy útil para procesar colecciones de datos")

# %% [markdown]
# ---
#
# ## 6. Ejemplo Avanzado: Bucles Anidados con Lógica Condicional
#
# Bucles dentro de bucles con condiciones que controlan el flujo de ejecución.

# %%
# Tabla de multiplicación con lógica condicional
print("\n=== TABLA DE MULTIPLICACIÓN ===")

for multiplicador in range(1, 4):
    print(f"\nTabla del {multiplicador}:")
    
    for numero in range(1, 6):
        resultado = multiplicador * numero
        
        # Lógica condicional
        if resultado > 10:
            print(f"  {multiplicador} × {numero} = {resultado} ⭐ (Mayor a 10)")
        else:
            print(f"  {multiplicador} × {numero} = {resultado}")

print("\n✓ Explicación:")
print("  - Bucle externo: Recorre números 1 a 3")
print("  - Bucle interno: Recorre números 1 a 5 para cada externo")
print("  - Condicional: Marca resultados mayores a 10")
print("  - Total de iteraciones: 3 × 5 = 15")

# %% [markdown]
# ---
#
# ## 7. Ejemplo Avanzado: Filtrado y Procesamiento de Datos
#
# Procesar datos con filtrado y validaciones condicionales.

# %%
# Procesar datos con filtrado
print("\n=== FILTRADO DE DATOS ===")

estudiantes = {
    "Ana": 85,
    "Bruno": 92,
    "Carlos": 78,
    "Diana": 95,
    "Erik": 88
}

print("Estudiantes con calificación >= 85:\n")

for nombre, calificacion in estudiantes.items():
    if calificacion >= 85:
        estado = "Aprobado ✓" if calificacion >= 90 else "Aprobado"
        print(f"  {nombre}: {calificacion}/100 - {estado}")

print("\n✓ Explicación:")
print("  - Itera sobre diccionarios con .items()")
print("  - Filtra datos según una condición")
print("  - Valida y procesa información simultáneamente")

# %% [markdown]
# ---
#
# ## 8. Controles de Flujo en Bucles
#
# Las palabras clave `break`, `continue` y `pass` permiten controlar el flujo de ejecución dentro del bucle.

# %%
# break, continue y pass
print("\n=== CONTROLES DE FLUJO ===")

# BREAK: Salir del bucle
print("\nUsando BREAK (detener cuando encuentra 5):")
for numero in range(1, 10):
    if numero == 5:
        print(f"  ¡Encontré {numero}! ¡SALIENDO!")
        break
    print(f"  Número: {numero}")

# CONTINUE: Saltar iteración
print("\nUsando CONTINUE (saltar números pares):")
for numero in range(1, 6):
    if numero % 2 == 0:
        continue  # Salta esta iteración
    print(f"  Número impar: {numero}")

# PASS: No hacer nada (placeholder)
print("\nUsando PASS (placeholder):")
for numero in range(1, 4):
    if numero == 2:
        pass  # Aquí irá código después
    else:
        print(f"  Número: {numero}")

# %% [markdown]
# ---
#
# ## 9. Casos de Uso Prácticos
#
# Aplicaciones reales del bucle for en la programación del día a día.

# %%
# Caso 1: Sumar todos los números de una lista
print("\n=== CASO 1: SUMA ACUMULADA ===")

numeros = [10, 20, 30, 40, 50]
suma = 0

for numero in numeros:
    suma += numero
    print(f"Suma parcial: {suma}")

print(f"✓ Suma total: {suma}")

# Caso 2: Validar una contraseña
print("\n=== CASO 2: VALIDACIÓN ===")

palabra = "Python"
tiene_mayuscula = False

for caracter in palabra:
    if caracter.isupper():
        tiene_mayuscula = True
        break

print(f"✓ ¿Tiene mayúscula? {tiene_mayuscula}")

# Caso 3: Crear una matriz/tabla
print("\n=== CASO 3: MATRIZ 3×3 ===")

for fila in range(1, 4):
    for columna in range(1, 4):
        print(f"[{fila},{columna}]", end=" ")
    print()  # Nueva línea

# %% [markdown]
# ---
#
# ## 🎯 Resumen Completo
#
# | Aspecto | Descripción |
# |--------|-------------|
# | **Propósito** | Repetir código un número conocido de veces |
# | **Sintaxis** | `for variable in secuencia:` |
# | **Secuencias** | Listas, tuplas, strings, `range()`, diccionarios |
# | **Controles** | `break` (salir), `continue` (saltar), `pass` (no hacer nada) |
# | **Casos de uso** | Procesar datos, búsquedas, cálculos, validaciones |
# | **Ventajas** | Código limpio, legible y eficiente |
#
# ---
#
# ## 📝 Conclusión
#
# El bucle **for** es fundamental en programación. Dominarla te permite:
#
# ✅ **Procesar grandes volúmenes de datos** - Automatiza tareas repetitivas
# ✅ **Escribir código más limpio y legible** - Menos duplicación de código
# ✅ **Resolver problemas complejos** - Con elegancia y eficiencia
# ✅ **Mejorar el rendimiento** - Evita errores manuales en iteraciones
#
# ### Próximos pasos:
# - Practica con listas y diccionarios
# - Experimenta con bucles anidados
# - Combina con condicionales (if/elif/else)
# - Explora funciones como `enumerate()`, `zip()`, `range()`
#
# ¡El bucle for es tu aliado para automatizar y simplificar tareas repetitivas en Python!
